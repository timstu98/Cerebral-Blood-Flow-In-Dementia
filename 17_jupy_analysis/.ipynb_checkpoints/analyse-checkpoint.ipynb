# %%
import pandas as pd
import numpy as np
import pickle
from pathlib import Path
from tqdm import tqdm
folder = Path.cwd().parent
import matplotlib.pyplot as plt
# pd.set_option("display.precision", 2)

number = '0011'

# %%
combined = True

main_path = folder / '_storage' / 'main' / number

file= open(main_path / "info.txt","r") 
print(file.read())
file.close()  

if combined == True:
    print('1')
    
    com_network = pd.read_csv(main_path / 'combined_network.csv').drop('Unnamed: 0',axis=1)

#     pickle_in = open(main_path / 'combined_network.pickle'  , 'rb' )
#     com_network = pickle.load(pickle_in)
#     pickle_in.close()

    print('2')
    
    com_vessels = pd.read_csv(main_path / 'combined_vessels.csv').drop('Unnamed: 1',axis=1).rename(columns={'Unnamed: 0':'step'})

#     pickle_in2 = open(main_path / 'combined_vessels.pickle' , 'rb' )
#     com_vessels = pickle.load(pickle_in2)
#     pickle_in2.close()

    print('3')  
else:
    print('1')
    
#     network = pd.read_csv(main_path / 'network.csv')

    pickle_in = open(main_path / 'network.pickle'  , 'rb' )
    network = pickle.load(pickle_in)
    pickle_in.close()

    print('2')

    pickle_in2 = open(main_path / 'changes.pickle' , 'rb' )
    RK4 = pickle.load(pickle_in2)
    pickle_in2.close()

    print('3')

    pickle_in3 = open(main_path / 'vessels.pickle' , 'rb' )
    vessels_alltime = pickle.load(pickle_in3)
    pickle_in3.close()

    print('4')
    
v = com_vessels
n = com_network
# Out:
# Time of simulation: 10 seconds
# Number of iterations: 500
# therefore time step is: 0.02004008016032064 seconds
# Delay for pressure drop: 2 seconds
# Time over which pressure drops: 2 seconds
# Ratio pressure drop: 0.2
# kp_constant: 0.0033333333333333335
# kn_constant: 0.0016666666666666668
# Date and time: 2020-04-05 12:39:36.199145
# save_changes: True
#
# 1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-080922909e1a> in <module>
#      10     print('1')
#      11
# ---> 12     com_network = pd.read_csv(main_path / 'combined_network.csv').drop('Unnamed: 0',axis=1)
#      13
#      14 #     pickle_in = open(main_path / 'combined_network.pickle'  , 'rb' )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/Users/Debs/OneDrive - Nexus365/4YP/python/_storage/main/0011/combined_network.csv' does not exist: b'/Users/Debs/OneDrive - Nexus365/4YP/python/_storage/main/0011/combined_network.csv'

# %%
def time_step_display(com_network,com_vessels,i):
    if i != 0:
        display(com_network.iloc[[i-1,i,i+1],:])
    else:
        display(com_network.iloc[[i,i+1],:])

    display(com_vessels[com_vessels['step'] == i])

# %%
# time_step_display(com_network,com_vessels,2)
print(n.columns)

# %%
def norm_ave(column):
    norm = column/(column.mean())
    return norm
def p(column_name):
    plt.plot(n['t'],n[column_name],label=column_name)
def p_ave(column_name):
    plt.plot(n['t'],norm_ave(n[column_name]),label=column_name)

p('Q_norm')
# p_ave('dphidt')

plt.xlabel('time/s')
plt.legend()

# %%
n.tail(1000)
# Out:
#               t  pressure_difference         phi   phi_min     R_tot  \
# 19000  4.275214               27.344   -0.371934  0.687308  0.000016
# 19001  4.275439               27.344   -0.371863  0.687222  0.000016
# 19002  4.275664               27.344   -0.371793  0.687135  0.000016
# 19003  4.275889               27.344   -0.371722  0.687049  0.000016
# 19004  4.276114               27.344   -0.371651  0.686962  0.000016
# ...         ...                  ...         ...       ...       ...
# 19995  4.499100               27.344  170.502276  0.893587  0.000009
# 19996  4.499325               27.344  171.253730  0.893587  0.000009
# 19997  4.499550               27.344  172.005318  0.893587  0.000009
# 19998  4.499775               27.344  172.757039  0.893587  0.000009
# 19999  4.500000               27.344    0.000000  0.000000  0.000000
#
#               Q_tot    Q_norm   pt_averaged          kp_p      kp_n  ...   An  \
# 19000  1.663524e+06  0.447953  6.494201e+07  1.513262e-07  0.003333  ...  1.0
# 19001  1.662958e+06  0.447801  6.494201e+07  1.513262e-07  0.003333  ...  1.0
# 19002  1.662392e+06  0.447649  6.494201e+07  1.513262e-07  0.003333  ...  1.0
# 19003  1.661825e+06  0.447496  6.494201e+07  1.513262e-07  0.003333  ...  1.0
# 19004  1.661257e+06  0.447343  6.494201e+07  1.513262e-07  0.003333  ...  1.0
# ...             ...       ...           ...           ...       ...  ...  ...
# 19995  3.015940e+06  0.812132  6.494201e+07  1.513262e-07  0.003333  ...  1.0
# 19996  3.015940e+06  0.812132  6.494201e+07  1.513262e-07  0.003333  ...  1.0
# 19997  3.015940e+06  0.812132  6.494201e+07  1.513262e-07  0.003333  ...  1.0
# 19998  3.015940e+06  0.812132  6.494201e+07  1.513262e-07  0.003333  ...  1.0
# 19999  0.000000e+00  0.000000  0.000000e+00  0.000000e+00  0.000000  ...  0.0
#
#                  Dn         c  pt_volume_averaged    dphidt         dApdt  \
# 19000  7.113194e-15  0.909091        6.494201e+07  0.000071 -6.869227e-12
# 19001  7.113581e-15  0.909091        6.494201e+07  0.000071 -6.869228e-12
# 19002  7.113967e-15  0.909091        6.494201e+07  0.000071 -6.869228e-12
# 19003  7.114354e-15  0.909091        6.494201e+07  0.000071 -6.869228e-12
# 19004  7.114740e-15  0.909091        6.494201e+07  0.000071 -6.869227e-12
# ...             ...       ...                 ...       ...           ...
# 19995  7.497847e-15  0.909091        6.494201e+07       NaN           NaN
# 19996  7.498234e-15  0.909091        6.494201e+07       NaN           NaN
# 19997  7.498621e-15  0.909091        6.494201e+07       NaN           NaN
# 19998  7.499007e-15  0.909091        6.494201e+07       NaN           NaN
# 19999  0.000000e+00       NaN                 NaN       NaN           NaN
#
#               dDpdt         dAndt         dDndt  dcdt
# 19000  6.869576e-12 -5.549358e-17  3.865863e-19   0.0
# 19001  6.869576e-12 -5.549422e-17  3.865863e-19   0.0
# 19002  6.869576e-12 -5.549487e-17  3.865863e-19   0.0
# 19003  6.869576e-12 -5.549551e-17  3.865863e-19   0.0
# 19004  6.869576e-12 -5.549616e-17  3.865863e-19   0.0
# ...             ...           ...           ...   ...
# 19995           NaN           NaN           NaN   NaN
# 19996           NaN           NaN           NaN   NaN
# 19997           NaN           NaN           NaN   NaN
# 19998           NaN           NaN           NaN   NaN
# 19999           NaN           NaN           NaN   NaN
#
# [1000 rows x 24 columns]

# %%
dph
